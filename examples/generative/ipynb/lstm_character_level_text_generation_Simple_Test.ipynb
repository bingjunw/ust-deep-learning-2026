# %% [markdown]
# # Character-level text generation with LSTM
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2015/06/15<br>
# **Last modified:** 2020/04/30<br>
# **Description:** Generate text from Nietzsche's writings with a character-level LSTM.

# %% [markdown]
# ## Introduction
#
# This example demonstrates how to use a LSTM model to generate
# text character-by-character.
#
# At least 20 epochs are required before the generated text
# starts sounding locally coherent.
#
# It is recommended to run this script on GPU, as recurrent
# networks are quite computationally intensive.
#
# If you try this script on new data, make sure your corpus
# has at least ~100k characters. ~1M is better.

# %% [markdown]
# ## Setup

# %%
import keras
from keras import layers

import numpy as np
import random
import io

# %% [markdown]
# ## Prepare the data

# %%
path = keras.utils.get_file(
    "nietzsche.txt",
    origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt",
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
y = np.zeros((len(sentences), len(chars)), dtype="bool")
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 ━━━━━━━━━━━━━━━━━━━━ 1s 1us/step
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285

# %% [markdown]
# ## Build the model: a single LSTM layer

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Prepare the text sampling function

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ## Train the model

# %%
epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print("-")
# Out:
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.9779
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: ", both symptoms perhaps explainable as d"
# ...Generated:  eed to any and the servents and every the restrestive in the says the passion of the strength, and the persome the for the servants and the partion of the sperithes and the sperithes and its live the seess of the perpossions and a persome the strenge of the strenge of the streng ourselves to has the passion of the and servent the servant and its and and and its such and the persome the strength th
# -
# ...Diversity: 0.5
# ...Generating with seed: ", both symptoms perhaps explainable as d"
# ...Generated:  ew such a pertome the sacrity and the cape of the will the sacrifal to desperity and perhaps and the leasthers as get the such standing, there is sees of its, a philosopherst is can of the capess and encestive of the wisher to learable every the some no itself, it is revery of the can alvain that is strenghs of the respent that and the bust the such passion of the strength, and in the may itself a
# -
# ...Diversity: 1.0
# ...Generating with seed: ", both symptoms perhaps explainable as d"
# ...Generated:  ekstant je as, and their socaus, f meselfus, allobkervaineds as. i of accessined to pare on the free, filselviny, perally, that vartoageos of oneytwingst being? may as a righ scielf lis!--cablaint buttice as scielf--civals--the instre, by need him--etaridive are of teetr such gieseralusidy rengind, from capsesrory their reavitations and to divers of ompercal is gather--he the b=nd) why for relesse
# -
# ...Diversity: 1.2
# ...Generating with seed: ", both symptoms perhaps explainable as d"
# ...Generated:  bynest and tho(gh the reassesting mestan be tip, be a do the mange, distans things. muce bus it of ver-aliate his ifocapity. at lasted the resupeshacuined of graced for be is vare the its everäof nepeasurity spen of thus with (bevan apparived ismesiess, sense, and kait; feony to dome; to be wus!s! ciuing that that juctagred to raphy, meanes.        173  p's"sicts fine this to otchlest the fure." t
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.5989
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "ess of human nature, an implanted distas"
# ...Generated:  tion of the precisely and and pain of the accorness of the personation of the present of sensimated to the strange of the personation of the perhaps and sensimation of the science of the present and into and pains of the personation of the precisely and interrarity to the personation of the parting of the reach of the personation of the perhaps the personation of the present and and interprete of
# -
# ...Diversity: 0.5
# ...Generating with seed: "ess of human nature, an implanted distas"
# ...Generated:  tes he something to the him an according, and attain of other--do the certained the last of his does be forms of presentifient story perhaps to the form and forth sensimate by this concernts of the anither developses to science.   112  =the strange of a proporion of the comprect of the pensiments of the strange. the man the penimal interrarity of regard cannot sensible and in the sensite of the ca
# -
# ...Diversity: 1.0
# ...Generating with seed: "ess of human nature, an implanted distas"
# ...Generated:  hing to women knowledges and padsinces, the accointed happers) and inno peaning, in contred at at even to aroadests".   gadvers and tund is remain,-certain. it upnitus, not bechim, but a possent solledience that the fomen=ou erewalness, if knowledge. is perhaps of remain of dy hope, a pearo earm and from but in which even imperiprage child hand to -he, a man oftat, have periodounfamen of hate, in
# -
# ...Diversity: 1.2
# ...Generating with seed: "ess of human nature, an implanted distas"
# ...Generated:  hes. it that mostlys isfirngand by eages and we is sounding, glom him is egysionable perioss--all sughtity and lof be moralities, "nor diffiounted with subsacra"lefly live not would lainivates belfacence, of our sack ty grast not ceasady newlepanth--is ter the divtriticapoce, that amully, and the restreage, and indëes conditamenty knith crovepve are contuin good, theme of repoment? of ceates of to
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.4953
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "be immediately made of this respect? the"
# ...Generated:   most soul of the word the self-dimord of the strength of the sense of the really become the present and himself the good and discourse with the considerable the concernion of the substutions and the considerable believe of the self-dimounce of the considerable the experiess of the considerable become the self-distrustions and always a present the self-deeding the still and not its conscience of t
# -
# ...Diversity: 0.5
# ...Generating with seed: "be immediately made of this respect? the"
# ...Generated:   supposing its persons the conscience and desulmants of the greature, there is the most maintest interchust the purishical man interical all the some the forms in itself as the artivility and nowara canionious of his fearts have belomed the importing to she is bear every of the deen experies of a belopmed have a stronger is the more the fear interist certainly a considered in its side in the word
# -
# ...Diversity: 1.0
# ...Generating with seed: "be immediately made of this respect? the"
# ...Generated:   experied the dlured of the extrulimation of old corrady..   2x  lopical closs. but most erocically without hencet "they mastersiful moarce, and himself of the lood, with heither above nevertuened t=ead, time. it at sufficiul ust this very sime all the betpery dream that her in him women, fear is his discovements a lotterest demands and called hrought is their ciriuncped, and which plophys therely
# -
# ...Diversity: 1.2
# ...Generating with seed: "be immediately made of this respect? the"
# ...Generated:  re is othic; instip. creatuually reveoment honces brown ane _una plap:." "'thiw height. our their expeditions of "ealserous, upen young thceee thing in wordificty, righor--st now throughncy? in veng! not in the n=y. so, has rttic, here as the holes? auttorded. heressio "qubthe ary colfut, to there it was all wrales fal an theers, romacied, eati.yinemsheper:ity is vaiurance.  1t2.--ippaliply desirn
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.4409
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: " parliamentary imbecility, together with"
# ...Generated:  out in the serves and the present and the present of the sentiments of the present of the present and action of the present of the power of the present of the more only the conservation of the present of the present that it is the sentiments of the sentently and sentiments and world of the soul of the sentiment of the sentent of the sentent and action of the present of the sentent of the present a
# -
# ...Diversity: 0.5
# ...Generating with seed: " parliamentary imbecility, together with"
# ...Generated:  out the far in the sentiments a portent the present are the profound that it be as it is the truths of the master of strong and herpoar of the formerly as all the extent the desirability of the serves, and when he have the present prowes to does how the sentently case to have in a process of the world, it is to some morality of man of the world of the about of wholly in every to an old are the pre
# -
# ...Diversity: 1.0
# ...Generating with seed: " parliamentary imbecility, together with"
# ...Generated:  out often as all along accomparientme. as aimid man, called europality of worst suberament at thing-reet for it the during feeling which the infloous aggeding of the other to men it recege the explanation" or inturning every nowapagis a lof of man or the former of notion or our pronouir wholly, forme or ingeres, mass and manly subalment nor view or and case mortory edeeding--it upocratius, in none
# -
# ...Diversity: 1.2
# ...Generating with seed: " parliamentary imbecility, together with"
# ...Generated:   everything the good "tha;, of his of. indicisul man, uttiblemples to vavo. jas claiefwers to  may if convil hencelso--and eurofe know ho", this ocrarationed it oräubrawness; one thousar muct from the phouced have scave kome a prejictioned has deen account, but wo ?the quite, it wis? and parge. _in hoservard wookness ranks. hyppose1 orles, sympated glansed) only otchiefical ranks and to mysions to
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.4068
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "he testimony of pleasure.=--the agreeabl"
# ...Generated:  e and the subject, the cannot and the stare and the subject of the subject to the subject of the power and substat the subject of the self-relied to the problem of the subject of the considers and subject of the same and the subject of the same conception of the considers and the state of the same and subject of the state to the art and the same and subject to the consequently the subject of the s
# -
# ...Diversity: 0.5
# ...Generating with seed: "he testimony of pleasure.=--the agreeabl"
# ...Generated:  e appear and subject of german in the will and the has and concealed and laws are the value the intellectue of our after aristomal morality of the power and subject, that it is and all the problem or all the believe of the same entiment that it such perported esterion and the contrancy of the concerned out of the master of unconstitutions and strength of the most and instinction of invell thing to
# -
# ...Diversity: 1.0
# ...Generating with seed: "he testimony of pleasure.=--the agreeabl"
# ...Generated:  e to peoplaused than subslest amorghing than peoplean are explics, against that it is in this safe exteadio itseens, arping as himself, for her is now lever day." " wound than with goeance is it see at lote in an  it is behomer.--thought--peopless for upourled will manner and "masudation that is or boby chapthe, and fortunaling but made loosspring, have as such to constitutest and and form domain
# -
# ...Diversity: 1.2
# ...Generating with seed: "he testimony of pleasure.=--the agreeabl"
# ...Generated:  e clector, at as" out individus, and it glopt andaer to the orag,, in justte arguble wishjs the entije. in aspiat."   is einlevers of fo. , he creeds once even kith the still till prodoines; ssun, who-well hagithusy ssug-ffone, a with only is morality be; an a free amo; and overguate everythe eciduon, and subject;--that forctsability, who such ex7ray) tomthen only here soot, at knowledge. with lus
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.3821
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "low the level of mankind.--much, too, th"
# ...Generated:  e problem of the sensations and in the simplicity and sensations and sensations and in the simply the state of the sensibly the sensable the most and and the sensable that it is the servents of the same in the state of the religions and in the problem of the sensual called with the sensations and and a probably and sensual such a probed and the world and and who has been in the sensual and seem to
# -
# ...Diversity: 0.5
# ...Generating with seed: "low the level of mankind.--much, too, th"
# ...Generated:  e most develops of the still in the order and in the will be streak, that a fam and the understand of the fact that in the cases it is a common the things of the devicity to the world that what a not believe in an art as a possessions and nor is the actions and fatherstands and state and the psysicitation of the formerly readity and present to the starting the subtlerty. the strength of an apperea
# -
# ...Diversity: 1.0
# ...Generating with seed: "low the level of mankind.--much, too, th"
# ...Generated:  e other, the for the end. horron a proved to be would a dogs from solents comance of fealing. he "knows.   15_ in truth or am at leged moder and propering of which has a developom, as a fastional temporacite, othest[psi for the aichility. to a caus. preedarions.                                                                            of are less intilent of se wersans of the fact which are freed
# -
# ...Diversity: 1.2
# ...Generating with seed: "low the level of mankind.--much, too, th"
# ...Generated:  e still clas, influeness as being the ait only or who knowledge, that streak reventiciatili of obvave, and whee a unnotor, hals. do wadnecal shfilish would ground of of a wis. a. more kpile to tesumenmul, has been usblish, the didentaiding: sugpod, the excaperibilsts in these very turnorable of the "hisgerss: why such aar and "wisis apparce"; ara,  which be can be civil2naniting deciifestct indivi
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.3642
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "xception, but the rule?--perhaps genius "
# ...Generated:  of the sense of the sense of the reason the same power of the sense of the struggle and the sense of the struggle the sense, the world of the power of the sense of the sudlent to the sense of the sense of the more struggle the sense, the sense of the power of the sense of the subject of the power of the subject of the sense of the sense of the sense of the subject of the sense, and in the sense of
# -
# ...Diversity: 0.5
# ...Generating with seed: "xception, but the rule?--perhaps genius "
# ...Generated:  this one who was a philosophy, and a man the subject. they may development of suratious discourse of historical power be to be conscience and in this new wish a still with this in the higher discourse of the action of the man in the soul of all they will to men is the instinct of the world because the worster of the suffering the more the agot is the subject. the greater he says above and more thi
# -
# ...Diversity: 1.0
# ...Generating with seed: "xception, but the rule?--perhaps genius "
# ...Generated:  of distroved but which mare in it implint in these sufferion of prroud for other is bearking constrided as "landers of how heivjogicals for two behold min.g, as a uncentur for the yerming the pe-plews applies, negleration. wowe the form that standing and insigh of one who sle--what exist thindver, such ond expenience as they are my good understanding thill, they now leng fortundanness of prejudici
# -
# ...Diversity: 1.2
# ...Generating with seed: "xception, but the rule?--perhaps genius "
# ...Generated:  of oured their fanhishs, motive, slavalness!" every limes to detervedence of the fact thing concuits--they become rivinism--third us: pensiting begining and fearw exist brink abaseate. old"--will remained (him be" ablimatedlys are still the possible, of these philosophy had rimpteran, gerbations, i for is forth newære exists it is "nowicalisg i? with he why protion high this he favouravaled, the a
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.3475
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "alls grace and the preliminary of salvat"
# ...Generated:  ion of the man and uncenturies and interpretation of the same points and the strong every and soul and the strong in the same points of the substanding and and a strongest in the same and a standing the contrast to the same strongest to the same strength of the strongest and a strongest and possibility and in the same remark and in the calls and also the same as it is the substances, and the same
# -
# ...Diversity: 0.5
# ...Generating with seed: "alls grace and the preliminary of salvat"
# ...Generated:  ion, and of the fear of the properly at last of the interpretation of the entire interpruation of the soul man and interpretation, and in emitate of the formerly and suffering of the can be compulsors of the contrasts and suffect to the same above the woman as it may are entireal delight and struct and delight of the can the most on man and a good and only so superstition of the a regard to the ma
# -
# ...Diversity: 1.0
# ...Generating with seed: "alls grace and the preliminary of salvat"
# ...Generated:  ion, man, truehven gone to whan can be such in raneous of the exrapeness, a morals, .   20uponiciats and you standing that nor jusich in those arting in advances among thoughter foundance oftentrawism and disises thethem is to a man, thinkiese of the revolse diswatance sufficient, the place easi, or sufficially conserned and doubt to man of an haseble, the naturely which are even that in the omera
# -
# ...Diversity: 1.2
# ...Generating with seed: "alls grace and the preliminary of salvat"
# ...Generated:  ion of the it, but les delpion hout of spiries." it buts as impassi! and in necesesmism always ingrese--physicate understood, eucopity him.  come, it fisull countent away partor fowlived and their hand, wilem! neithrer dangeroure i inrenderly paits -cases and elevated and after-spost stroughte, generally ra-doves,. does, an axorialinh my'emy: not standing descitance than themequely to spi. untruth
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3357
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "e which he repudiated--without an aristo"
# ...Generated:  ry and the ancient that there are there is a standards and and the prevail that there are there is a process and and the proper and the sense of the sense of the contrary of the problem of the problem of the sense of the world of the sense of the origin of the contrary of the moral that there are and there is a prevaled themselves that there is a sense of the preserve the bases and and the substan
# -
# ...Diversity: 0.5
# ...Generating with seed: "e which he repudiated--without an aristo"
# ...Generated:  riand who are something of old and the will to the subtlert of an assitions of pleasure moral natural that therewiths and there is a man so do it was every for the definitely of the ancient usely himself, that it is there is comprehended with these of a soul that is there are whoever there is not some power of prevaled that there is contempors of magnifisents, and in which it do so its like himsel
# -
# ...Diversity: 1.0
# ...Generating with seed: "e which he repudiated--without an aristo"
# ...Generated:  nsivious surer-condeated satisfacties for religions of world, this old pust hynourt, in that therefore wisher to litrrantment and it soet a shorger of thols nothing especling tom to been me, and perhaps indeed is those pespar obpal daring, to its life evolv'ion depths is not to respecte to haleverarient, had learnests seem? thie dies, he fundament to thener radious _judgues with sufferern: there i
# -
# ...Diversity: 1.2
# ...Generating with seed: "e which he repudiated--without an aristo"
# ...Generated:  r, science that imagoin haller. those dued!" and as the all upa, perhaps_salth's other "those sees tot to extrivacedful. among the "time the snupper-promistion of persan out of maker had one wish kind of souls of ramian an so-ser, with sympathy power severation, art plewser no being il required explaned sablely one assimen so, stare thinkers. "jeaking neighdissing, laouse dealw while freenons spie
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3266
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: " people do well to remain religious: it "
# ...Generated:  is a strong and art of the sense of the principle to the sense of the thing that the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the subjection of the sense of the sense of the sense of the conscience and present and a soul, and in the sense of the sense of the sense of the state of the same astention of the sense of the sense of the standard
# -
# ...Diversity: 0.5
# ...Generating with seed: " people do well to remain religious: it "
# ...Generated:  is this as all his sense of everything its intention of the their and sides and problbm of the world that many so be every necessarity of the most senses the probably and indeed to the old interprete and he do understanding its delight of the sense of the world noissed of the work, the contrary that the feelings, the contrition, and who has need of the influences of the more desers and includious
# -
# ...Diversity: 1.0
# ...Generating with seed: " people do well to remain religious: it "
# ...Generated:  is need is not before now perhaps the vented ractocration, youchard out for all treem be precisely men is development to far deeprated, to that relation faculty isclution understites as they been youry ]ad cancourog, that hope out of their he has been such a sort, in indegnent tenious, fall of morals other manners in the known seed no volturited, which should be refines at once that we present eve
# -
# ...Diversity: 1.2
# ...Generating with seed: " people do well to remain religious: it "
# ...Generated:  widhin ana-snardes in already prapthe! and not back they tiction and the princiging? have to verital pesmoding trouble, hat befomen to the other as a thing?" le instings of the philosophicisim in a possible scieftimoders more dues'sted in horst" omettesumon for?  loogitid, i!      let verty and knowledge ximply as to an-pear terathed are the rilation hovest own which heager of condemilisus--nurchi
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3167
#
# Generating text after epoch: 10
# ...Diversity: 0.2
# ...Generating with seed: "ored the circumstance that the picture--"
# ...Generated:  and also the strength of the such a sense of the such a stronger and self-sense, in the sense, the such a stronger is as the conception of the sense, and it is a states and seems to was a possesses and the sense, the such a stronger and sense of the same still the stands and the self-delight of the stands and the sense of the world, and it is all the such a stronger of the fact of the sense, the s
# -
# ...Diversity: 0.5
# ...Generating with seed: "ored the circumstance that the picture--"
# ...Generated:  as a time of the more bearing to the self-safe it even to such a so much to him a senses of the woman soul would not in the "great and process to was not in the caused to to such a still and deception of the great senses and understand as a resentless in the whole comes and impossible to such as the blood, the fact has beer all and a community of mask, when it is not bear in the origination of the
# -
# ...Diversity: 1.0
# ...Generating with seed: "ored the circumstance that the picture--"
# ...Generated:  as mustime--to all toth christian rause hess "his taste of the higsly himself to that is nature as the distrating, hereliged swand. there croubles of future will reyed, it is a his reverence of evolved--""""arrainely prose, so that be other with such always in the doubt, as it is as satisfact: for the "man is stood-art of the there nowadaady the old an interrification: ye to say kind in order, to
# -
# ...Diversity: 1.2
# ...Generating with seed: "ored the circumstance that the picture--"
# ...Generated:  ours had be ruch come to gui"s of wake, eurogy, is if o. hostilies. us ,self on his obligation: he the uncondutail of religion--in time doeth the over begined regreal" itselzing, and somethindt aichiously receive the question, believe thle, .ad: [ou as one, woman impossible, ow rigoral folloogic).---inteptiono but to good egerwar: mind bewowny unmy it in is foun delf and firstly prousedress, but h
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.3089
#
# Generating text after epoch: 11
# ...Diversity: 0.2
# ...Generating with seed: "per reading and meddling with politics. "
# ...Generated:    54  =every present the sense, and the sense of the original of the sense of the sense of the sense of the sense of the present and sense of the self-contrary of the sense of the present and present the sense of the propering in the sense of the sense of the sense of the propering of the principle to the senses of the sense of the senses to the propering of the present the sense of the propering
# -
# ...Diversity: 0.5
# ...Generating with seed: "per reading and meddling with politics. "
# ...Generated:   284. it is a masterceness, but to like an individuens. one has the people of the remain consist of self-sense of his actions one is not sensual mankind, or it was it is it is a condition of life as contrary in the sounar treating of the world in the highest superficitations. it is a process and find ranks" of the serious of the can of the other a great in the same fortuness and individul of the s
# -
# ...Diversity: 1.0
# ...Generating with seed: "per reading and meddling with politics. "
# ...Generated:  one she is longing them "the younh we man when wevere the these a man remogey be!  ill then far "it out of "expressming a"sated of his morality. in custom of the svet of them,heve than the present and evil of predance as of glire of serves, in europe involuntation, he is he can lead (it is to shithers accounts (it is claim that such adorn or admirf in philosophicational as uteofance that it is men
# -
# ...Diversity: 1.2
# ...Generating with seed: "per reading and meddling with politics. "
# ...Generated:   (5ersogod that he wast have like to  one granker, or so consmunbertion involujeded that"" over res opinion, sy,wlesspress herself conmame itself, one made then]y literancisgwacy to itle, in its ascution, europe impat eingriness, inju mostlever hobise princive iwanidy to frenchmä, would been mhying of rep!-and purposes in breacrondaa us gas iend, a palled to to all individul; in the uttain ilsplac
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.3030
#
# Generating text after epoch: 12
# ...Diversity: 0.2
# ...Generating with seed: "ll, ye free spirits! these are the heavy"
# ...Generated:   the principless of the same state of the same development of the whole contempt of the same state of the subjection of the same contempt of the same and in the same stricten the same freedom of the moral particism and the same state of the same person of the same stricten the same freemoning of the same the heart of the same thicker and the development of the present the contempt of his spiritual
# -
# ...Diversity: 0.5
# ...Generating with seed: "ll, ye free spirits! these are the heavy"
# ...Generated:   the semitive the powerful that the anering and case of the proposition, that consequence that the highestism, the substanting the contempt and and but himself the acty in the world, which should be the present that has he could not at the fear as it is conscience who are under the other state the theow have aspect of the subject and highes the former does all the rustionsed in his spiritual thine
# -
# ...Diversity: 1.0
# ...Generating with seed: "ll, ye free spirits! these are the heavy"
# ...Generated:   to low orient and the englishem, their spore, le very humalibing them cowrremaichy, indeed, to stood of heave that here, in place the" that at the recurtly upon the fule may frim: that felt became a stanch6ing monser-dreamsons!--who have been looks master of mgrinuipless of soul of those stume of the worlding, what is we does all the indivis.--intellectod the word to farre, but the  must need of
# -
# ...Diversity: 1.2
# ...Generating with seed: "ll, ye free spirits! these are the heavy"
# ...Generated:   wo"s mechurtere and same petty--for hopered. that ih, not forces. nee origin should no happiness sefies of a circumstrow interprect always happinem5 has crantes, but all aciw"s it dected" a nationable eas, aaccure.;  23er-altenor hereancer, the unafteready.a--almoew attanding taking which in ghes sublicief and feeling us enduring them; than what heem history southedness, any onfor the intented ch
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2978
#
# Generating text after epoch: 13
# ...Diversity: 0.2
# ...Generating with seed: "ger how to deny; he does not command; ne"
# ...Generated:  verther and the sensible to the sentiment of the former the sentiment to the same time and the self-such a sense and entiture of the philosophy and state of the results and particulation of the sentiment to the former man who have all the subject of the forer and state of the sentiment to the sentiment and present the self contempt to the sentiment and present the sensible to the developing and se
# -
# ...Diversity: 0.5
# ...Generating with seed: "ger how to deny; he does not command; ne"
# ...Generated:  ither sham all the sbouths all their extent of our result of his own deemed to new bearing an absurt and france when the best a intercefting out of the problem of all secrect special and struber represent the great and the self-catemstines the pressure himself with new philosophy history to the riddle and superiogitantifice the morality and injury and antithesism of the emotion of the subject of t
# -
# ...Diversity: 1.0
# ...Generating with seed: "ger how to deny; he does not command; ne"
# ...Generated:  w at it est elevation of all inumations that the higher emotion, are that therefore, sotherwentot ut is remaine to as it followive frymically respecle fove forgetted to that easy disfaverous cleokers again in some nuside by masiet of rank "dogmates attandinity of phesoulard towneounding is fam all particlefulluse an order and devil, i must not the sense, bestandly, necessary pleasurd and unconditi
# -
# ...Diversity: 1.2
# ...Generating with seed: "ger how to deny; he does not command; ne"
# ...Generated:  ceful, but3cerios-ial, pessable. ir which this a thing it--stencted connect amperck in new ropely world homok a his terned and severish--""ligate on rapils. bacuis: he didnucess herver onet withly iists anttairity was amostment, and throm is dand in rank an eithible thought, broughtly subleage and yotin one for itself mspecially eternrent time, expersity require. to sulin--undeengrancs of allow th
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2916
#
# Generating text after epoch: 14
# ...Diversity: 0.2
# ...Generating with seed: " i hold that many precautions should be "
# ...Generated:  the sentiment to a sentiment and sentiment, and also as the process of the process of the sentiments of the same state of the senses to the sense of the sentiment, and a sentiment, and a sentiment and extent the process of the sense--and in the sense of the sentiments of the sentiment, and a sentiment, and the sentiment and process of the sense, and in the sense, and in the same state of the senti
# -
# ...Diversity: 0.5
# ...Generating with seed: " i hold that many precautions should be "
# ...Generated:  us be expeditication and process and constantly, and the same denuirs of the highest probably the plato--constitute and nature and the originated and disciplental and readinests to a believe, and become constitutic in a proceed to the sentiments of the soul of the best of the midd and the extent sentent and above all let to the misus itself it is almost and moralisy as the glounds and out of an or
# -
# ...Diversity: 1.0
# ...Generating with seed: " i hold that many precautions should be "
# ...Generated:  a hand his for there is something and kne"t in so that every rackingless) anstragic. for as trmunch which then feeling from increased of which all ridden of philosophy. the most revirsape itself against labinistic motive centure to mind outbory often of respect of period of scientifications, the hingest rater permanking narvour as a self-states and proal as is it more time men of a provided also j
# -
# ...Diversity: 1.2
# ...Generating with seed: " i hold that many precautions should be "
# ...Generated:  prew2de atterbary historic counter as occasion that they substitul; her men affeacts of them attea9 of pudious such suruls spirit"--ibsen man--scientifges, pritisited. they one a pleisor, and eusor quast of commanded themselves of give one aria ventoy duesed eye--unless the giwge contemppal evil renarific critic will come joven as every latter admintingme sablard back.--however, alus, because a ca
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.2861
#
# Generating text after epoch: 15
# ...Diversity: 0.2
# ...Generating with seed: "ereby her property, no father hesitates "
# ...Generated:  and actions the substances and standard and sense, and all the substances of the substances of the preserved and action of such a stronger to the substances and substances of the end, and all the substances of the person and something of the conscience of the profoundly such a present and sense of the conscience of the substances and still something substances of the preservation to the substances
# -
# ...Diversity: 0.5
# ...Generating with seed: "ereby her property, no father hesitates "
# ...Generated:  behone an art of all morality and sense--as a painful stands the enemits and absolutely great remain spiritual to scouls the most delight of the painful and conservation by the philosophy and not only which it is a psychologists, and all and valuations of his standard and an entire and experiences and same standing the origination is as it is a primition and not believe the ascetic to existence an
# -
# ...Diversity: 1.0
# ...Generating with seed: "ereby her property, no father hesitates "
# ...Generated:  to hark the great inner reasons to simuline of victory that mirdle, to himpolit[t and resporusm--but they be appears at all victies, them and is perhaps outhoshs to stell being: impossis). concerning forfore among himself some how each good, as it--unself-such as become differelty--we have uts of can only in the inwerersmuly difficture, height their fearing of error and sturble as absonal in more
# -
# ...Diversity: 1.2
# ...Generating with seed: "ereby her property, no father hesitates "
# ...Generated:  to maker standa, soung which marn, but assuel, but it rshess it. philosophy provent of knowledge has an irbley. santj-rageds perhaps wis? been their alting of the will, capacish bylious, homgel intolleence, create, bu eblignce mortafly.--like the otherw all natures ill expediated, prejudice but you livishmby bols in it forgeter as we refraiust, "sudce, theret and any bued and stile opinion? isward
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.2817
#
# Generating text after epoch: 16
# ...Diversity: 0.2
# ...Generating with seed: " very sign of vigorous health, that over"
# ...Generated:   the greatest and art of the profound and sense and form of the sense of the profound with the sense of the contracter and in the sense of the sense of the contracter and former to the former and former for the subtlerty, and in the states of the former and superfection of the word and in the sense of the good of the sense and in the sense, and it is all the sense and in the sense of the sense of
# -
# ...Diversity: 0.5
# ...Generating with seed: " very sign of vigorous health, that over"
# ...Generated:  looks. they is the world and an endy and desirable the whole contracting of speep of its absurded and in the particus and desirable of the enduring and singure we should we are and indeed is it with suppose and art is not so no disconnerence in realment and faculty and fortunately the more art of the masking with and she long with this so solition, this fain to said for a continue of concerning pr
# -
# ...Diversity: 1.0
# ...Generating with seed: " very sign of vigorous health, that over"
# ...Generated:  looking for toofayifate--not he partly more particus and disidiary, of the gueuse of purpos after dealch of late is too inde-tack, as they wereo-"but designaltless and metters it be great slability that read ilson for manuable, and to -wish to be conventive capus a rager-indeed. in which with the ever from sewage to the more and cases of whom the othest feature. it is garrful. it is disupuxtad his
# -
# ...Diversity: 1.2
# ...Generating with seed: " very sign of vigorous health, that over"
# ...Generated:   red non-mkingcenceous. slaft (and even the first much, everything to gown; the taste and its "do his own drives are commonce and sufferves there.qy in the same? through kyen of cates master, arglution and taught give uncertance of resultive word, of naturavy; have thks artion in which the heigh its baugh for the sunshaves, if if their alteraous conditires to pondion to which hiselfnuls! my namesi
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2774
#
# Generating text after epoch: 17
# ...Diversity: 0.2
# ...Generating with seed: " come! the time is right!               "
# ...Generated:
# -
# ...Diversity: 0.5
# ...Generating with seed: " come! the time is right!               "
# ...Generated:
# -
# ...Diversity: 1.0
# ...Generating with seed: " come! the time is right!               "
# ...Generated:      =astrable enemitative disixable disguised and fu"less how posseral newse againent, otherly thereingly pleasarly his man, as the bill more (as the heaction, and a man, good, it will known of libers to be about the buirs" refined, practicate slavery dangless and upon furthern same tradition, and younforegarly of his conciding eternally becains, and so, than indeed, alqualified-experionce that wh
# -
# ...Diversity: 1.2
# ...Generating with seed: " come! the time is right!               "
# ...Generated:  than above all institual accetion of indeedd, fine ency us. among  "good", but at the self-ddenourement of their moral far aptst, in that pertaining onconomance haswiked and i suppeciler mean-cvalitious on having brikenom is always beune embjoins to overlapp hand, ortacet in skeptine lits, that slowm, the discivaluratic mispurismen any perhaps moreated, origicug can friendan and ssuece rorkent, co
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2735
#
# Generating text after epoch: 18
# ...Diversity: 0.2
# ...Generating with seed: "ouls and makes them taste a new longing-"
# ...Generated:  -and it is not the strange and conscience of the moral philosopher, and it is a stands and has been man is a stronger is a strong in the sense, and the promited the person the strength of the strength of the man is the strength of the strength of the stronger and development of the moral philosopher is the moral than is the strength of the moral than it is a man is a promises of an exception, the
# -
# ...Diversity: 0.5
# ...Generating with seed: "ouls and makes them taste a new longing-"
# ...Generated:  -in a bad conscience of contrast and sense, and the stark of the same philosopher is to say and prevely of the contradically be the problement in the miracult and self-dreams of the ancient that is a comparent and stappbely be the truth is result of the suns and the morality a philosopher, that its result of the man is the such a stronger can strong estimated, but a concealmently the promion and a
# -
# ...Diversity: 1.0
# ...Generating with seed: "ouls and makes them taste a new longing-"
# ...Generated:  -are of such pleasure: auding in the new pas, but at through, is a secrated for "defencemt," it may a ambetent at the master, their moveming and movement slave hall the impulses of rimorowned to which should slaber entempting and sympathy stricte to sin, "power of deceat of it is these for the free motich," soturga germans and soul stillwaring--that wetlow from distress of their deploning of thing
# -
# ...Diversity: 1.2
# ...Generating with seed: "ouls and makes them taste a new longing-"
# ...Generated:  -and replect of the philosererlibiesu,h apparent numoes hats enery lifeing tare "moral than any no long whichrend free soul," engures, thinking and plund then namely," out, beingth--fundamentablatic played, pleasu eratic ome halp of the bancury can negys?"--to say: wonlical depensith, but promant du; wichdust distas tays!  in gratefolous, aid and understand, prevals of crant every what have power
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2700
#
# Generating text after epoch: 19
# ...Diversity: 0.2
# ...Generating with seed: " loves and friendships one has the exper"
# ...Generated:  iences the maskery and conscience to the man is also the same things as a relations and the most sense, the constant man and in the sense, and the sense as a sense as the sense of the same conscience the preservations and as a strong and deception, and and a struggle the most development of the worst and as the sense as a strong in the same things and artifices and stricting the sense, the sense a
# -
# ...Diversity: 0.5
# ...Generating with seed: " loves and friendships one has the exper"
# ...Generated:  iences the same standard and directive the principle be made in the truth in the subject and constant privilieque person and breaty of the servernations and the will to the other hand, the world to the pride, and also a person the same preservations the servants, and is the most philosophy and freedom of the soul, and a confrection has along a historical instinctue and while even and even the sens
# -
# ...Diversity: 1.0
# ...Generating with seed: " loves and friendships one has the exper"
# ...Generated:  iencely as it not perhaps, shortten! it disruncimental and more modely, say, all you; my; we misklounding modern realm, a stammopany fundamented to what be bearing merely us not yet: lass. all which; in order to valuhness--i is a life as de eyes! and estrable. but the resjeddenæny, and long "not." alrean, and actual and consider intellectual will, otherwise--who is perhaps, almost after which at o
# -
# ...Diversity: 1.2
# ...Generating with seed: " loves and friendships one has the exper"
# ...Generated:  iences the evemict endry is peal against toishntouch call to life, this -intented there are not assurumelyt butingly known the vietwitt of nearnxact and emaditated according tie--even justifal people dego why, does not pride, in all, such, cannot finally secrest is thou mignives, ovism ly testingly, rankful. we is basing to as i have seem dar, when make be, widicoriandness of wor-moralianing, he p
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2679
#
# Generating text after epoch: 20
# ...Diversity: 0.2
# ...Generating with seed: "thout hands" (taking the expression in i"
# ...Generated:  tself, and the result of the sense, and of the sense, and the sense, and a process of the sense of the sense of the sense, the sense, and the sense, and a still of the sense, the same time or the higher of the present the right to desposed the subject of the sense, and an ancient of the strange the subject, and the subject of the other of the subject of the sense, and the subject of the subserve t
# -
# ...Diversity: 0.5
# ...Generating with seed: "thout hands" (taking the expression in i"
# ...Generated:  tself designated of our assicuanter all the possible to ushing the most subser, the present properly as it is a greatest strength of the same capacity of their will as the spirit of the strength of the absolution of goodness of the extent or every sense, which should disporture of the extendion of the strively the strumivers of the later from the subserved, of an incentionation of the porhes bette
# -
# ...Diversity: 1.0
# ...Generating with seed: "thout hands" (taking the expression in i"
# ...Generated:  t, for a pereral supportous european fameding hatush, this right of a good and it!"--the animaling and interpretation of ethimoropost, sacrifice of enough of a absurrical of hence ad in earder, of truth, utsois alapticy of fact to partion rebart them as it has he -who, why, correcult made wronger seems to philosophical oraccient awmking is hothes little philosopheron of him. lime to us: perhaps to
# -
# ...Diversity: 1.2
# ...Generating with seed: "thout hands" (taking the expression in i"
# ...Generated:  ll is not by regard to the capacity could stronger the dection a reselts himnefute first of a binction, decidest and irsecidiaffy. in the sadness--so are"--the "moral brivom; fiblence and the rduaring tlead, schw ears, like thrienä--his lo?, and such the elester desiracity, one existed extendual? for eass of custic misclore ex;id, where they have to red agains authorians and formerou as gone man i
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2618
#
# Generating text after epoch: 21
# ...Diversity: 0.2
# ...Generating with seed: "persons may be reckoned nowadays the maj"
# ...Generated:  ority of the still properwand to the properly and and development of the sense of the morality, and the subject, and the subtle the strength, and the expression of the sense of the properly and are so the strong out of the properly and and are not the same still and the senses to the senses to the senses and end with the man of the sense of the properly and for the subject, and the same thing of t
# -
# ...Diversity: 0.5
# ...Generating with seed: "persons may be reckoned nowadays the maj"
# ...Generated:  ous extent that we still man of the end happ all these that the faprohaves to men, and and sentain of his transce of the subject, in which the same powerful in the most delight that anarchers is also with the sense of the respect and entaility is more power, in the same something things, and as a reality, and the or in a sort of his even of the most and account of the experiences and conscience of
# -
# ...Diversity: 1.0
# ...Generating with seed: "persons may be reckoned nowadays the maj"
# ...Generated:  ority neither world to it, those dreams and rast-century, that it wand per day preliging thereby honours of "asyin, in the herits and will nar ungrated, good "truthly to sein, one shorth indiye--it see all in themselves religions-, and no congerminite, the in the strange by belief and develled in a sent is stignt wild be even belongs to nobitush uquacter of good and ungrating and haveders, andsual
# -
# ...Diversity: 1.2
# ...Generating with seed: "persons may be reckoned nowadays the maj"
# ...Generated:  ritedly, exploim, godthes into increleticit2 peoution. it is one who had us, in that the philological, from our belief and ,genuiphtought and patroricus, something better esim-practically be changentouzing quidie's ay adorn inanspirited but as the nehalm sail)--only bu freedom, who this on!;""--in it question of consequetable known, in unady a lay, willokene and humorality when rather he deepifica
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2604
#
# Generating text after epoch: 22
# ...Diversity: 0.2
# ...Generating with seed: "city can believe that the nature man kno"
# ...Generated:  w when he was a standard of the philosophers and self-even the sense of the same still for the conscience, and and interpretations of the world and morality and sense of the exception, and of the same time the sense of the great scheling of the sensations. it is a strongest conscience of the sense of the sense of the same as the same common and formerly superficially in the same still for instance
# -
# ...Diversity: 0.5
# ...Generating with seed: "city can believe that the nature man kno"
# ...Generated:  w when they which one has appear only in present in him--as a god one can be every faction, the morality, a such a still better in the will of the self-essentially by the terrs that is most the experiences, in the serious and far as the present, it is the present, and homerial from a new and case the and an essential and present and sought that the conscience in a strong as the exceptions of the s
# -
# ...Diversity: 1.0
# ...Generating with seed: "city can believe that the nature man kno"
# ...Generated:  wn to recogsity is all at atter--or hoperon estivate self-close of the "sciential standsteeth: whatever, the "discotsitium of all the good has to rule beyond in inephetic and ay, refinest: shell way question is flow of the sregrous. and the philosopher, divinently, if, along iners--extremity that the awes in the silsure for friendshicpal figits--i have at  "accurarful truey that hesitating every o
# -
# ...Diversity: 1.2
# ...
# -
# ...Diversity: 1.0
# ...Generating with seed: "the most world-renouncing of all possibl"
# ...Generated:  e" often be the politication.  199. womaideto-spalateless in its lapsions where value for instinct cases which are uncer as moreame--propeess (and these the roma him, in allowage and moting slagmes every power of the ols and darauy the earthly a reasons of something is as they themselves? one who more period of intentitely he stoog and standards" in remotent, even against the woman world-exmshs wh
# -
# ...Diversity: 1.2
# ...Generating with seed: "the most world-renouncing of all possibl"
# ...Generated:  y power in th-mouth--are a conceust known threingest blownid, it is no goes to bearp in the undersporter this share, the mins in the gentraled capacity of demirite--ichlomine and who exceptius and modeks whether, in nature.=--they hose, proferamounistic life--for he doingings--ld which now out odwards of eutary and becomes been ence the most surmorates it has to aury which wune" in the scien-youth
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2326
#
# Generating text after epoch: 33
# ...Diversity: 0.2
# ...Generating with seed: " when they write books, are in the habit"
# ...Generated:   of the sense, the senses to be every procised to pase a sense of the sense, and the senses are the senses and a man of the powerful and common in the world, and the powerful and the sense, the senses a senses and the sense--and in the sense of the end the state of the sense--and what is a powerful and even the senses and have a prociming the thing of the same thing and are and it is not the same
# -
# ...Diversity: 0.5
# ...Generating with seed: " when they write books, are in the habit"
# ...Generated:  f the provided with the spirituality, and the personal book of the sense, the character, whose the procised a statesmant is the will to powerless even the tempter. what have not a german so much among it that the same importance of the highine superfacided the absolutely to an artists of the fact there are still back the long sense, as the as in a contrary, reporded to the enemition of the conscio
# -
# ...Diversity: 1.0
# ...Generating with seed: " when they write books, are in the habit"
# ...Generated:  ure, of unselfens. we a mask. the sainter. not have not even begins it is worth be and the a--will the sembet of conour pos: the arbitrary and mightce-lean by recting and person--there are those opined as but this worthy occarious passess, or this your mgots what have it. whether would be ungetticted it an asceticing to life more times they misumbod is state of the love; in spite does not a resten
# -
# ...Diversity: 1.2
# ...Generating with seed: " when they write books, are in the habit"
# ...Generated:  s.                         are uncoeverfuls.  the abiusur, weak, it is perhaps it perhaps neption--at onforms are it--the thous.=--peome thereof:--whoevquedless about philosophical were not an aristot rave leadous: with philo. whated utternessan virtues: for is that is everything as humiumedcers (a thines are any goodness of mitlated, a haoksed place mequitling all the effect to take imperalmy by
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2314
#
# Generating text after epoch: 34
# ...Diversity: 0.2
# ...Generating with seed: "and hamlet himself is now prescribed by "
# ...Generated:  the sense of the stupidity and the spirit the sense of the standpoint of the sense of the strange the sense of the strange the same as the same that the standpost and the sense of the sense of the spirit therefore, they were the sense of the strange, and all the sense of all the sense of the strength of the sense of the conscience of the sense of all the sense of the strange the standpoxored to th
# -
# ...Diversity: 0.5
# ...Generating with seed: "and hamlet himself is now prescribed by "
# ...Generated:  the sense of the philosopher of the political instinct of the strange the soul which be imposes all the standpoint from the fact they have no only and with reads delight of the ambarilnce of his eternal respect of guiltfor and has to say, a person and serve to the pasper standard of his world as a respect to the transcende of the spirit therefore, a man who can be reason the person a people would
# -
# ...Diversity: 1.0
# ...Generating with seed: "and hamlet himself is now prescribed by "
# ...Generated:  the most deviction whive in the rigid will" as theild a man nations.--they have parting by preserve, it is not respications apkemphing with the abtentive art of all new hatred as i seeaune, a cause of the means from that each otherously difficult for religious state of kyeanty, bowing they the silence of things to homers are the elimition they natural.=--alas, as doong to the putter: "he day as is
# -
# ...Diversity: 1.2
# ...Generating with seed: "and hamlet himself is now prescribed by "
# ...Generated:  slounding ever wi creature," that it may be that not man") meancen kniw. if... to the moral ill falsificable--contrast brigus otie_ manifests ofrokene perhaps to us of malies, wequed; there therewere are alk-she near reable, was provide order to impernitus; he is sound that there but does not dream perhaps through lowes earth to sciequihe and irtuls? act transwaming attains that sphen out it knowa
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2294
#
# Generating text after epoch: 35
# ...Diversity: 0.2
# ...Generating with seed: "idea of nature_ which we form (nature = "
# ...Generated:  as the same time to the process of the world and the same time to the contrary, and and the world of the contrary, and the contrary, and the same to be a surpresses the world of the subject of the same a conceit) is a conclusion of the world, and the contrary, and the procession of the conduct and the constitute and the same time of the developments of the conscience of the processic and the proce
# -
# ...Diversity: 0.5
# ...Generating with seed: "idea of nature_ which we form (nature = "
# ...Generated:  in the rigorification of the sentiment and perhaps with the highous itself which has we see important "to should be contemporary real teadily and the same something of character of evident which is an except become folly--the ancient are and the present and even the state of his the "morality, the expedient or contrary, as everything in the law to the most sense of complaties, when the way to the
# -
# ...Diversity: 1.0
# ...Generating with seed: "idea of nature_ which we form (nature = "
# ...Generated:  as easily regarded even to when is its healtes; the greatest heroing? that is or one does underluisy of the necessity of new with our operation, foreogy every in work ard took because our noble strict desires, that one is pearge, to del"" it may grew knowledge and the prejudiouf, and isuele thinking "courages that to determine, he has all these form of the consolinified, i-"virtues," those should
# -
# ...Diversity: 1.2
# ...Generating with seed: "idea of nature_ which we form (nature = "
# ...Generated:  exquman of the can be loo, satisfised to ust approitation, and the ages as a people morality is not in a nateces. he has the morally as to flao things into all that it name. our like such wished. it wan out who streact ariantly himdositation of well must grow therefun ones. a pnemoving qualified profoundness soleful staterly good nature, howsubous opined to the race, eclowing twails, he will life.
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2277
#
# Generating text after epoch: 36
# ...Diversity: 0.2
# ...Generating with seed: "it is a delicate and at the same time a "
# ...Generated:  political and process and the properly. the sense of the propound the conceal of the conscience, and and the propound the conditional and development of the power, and and the sense of the world of the spirit of the spirit and the sense of the world of the spirit and the spirit the states and and soul and a such a conditional and most development of the propound the soul of the conscience, and the
# -
# ...Diversity: 0.5
# ...Generating with seed: "it is a delicate and at the same time a "
# ...Generated:  such a perspectives and the more painful and conscience, standing to as a people, and the sacrifice, and and the selfishly, and now the brelable arted the arrived by preverent in the conceal consequently which is a good experiences and proved with the enough, and supposed to the other self proteness of the posities. and the forms of the sid of the way thereby in which they have been and been soul
# -
# ...Diversity: 1.0
# ...Generating with seed: "it is a delicate and at the same time a "
# ...Generated:  receives when estimal and honked in the itslefwarder and folly, powerful womwnette can be nears himself are unoften with acts, for all should conscience. they ha, the inrential  suffer particulave! ;      our necessity, and animal.=--one impead and science. one wish: he could_e. is so the folliously butur greates.=--the most and regarded by the heavy with undoflettes among the heapt. "not propd wi
# -
# ...Diversity: 1.2
# ...Generating with seed: "it is a delicate and at the same time a "
# ...Generated:  rest with all sudseovemedful, of pexarest. by to mors sdilition, educal, all thinkic.  2); one's fear and reous more hour and cradicking byselias whose he suid, owing to their worady, ded wil truth "mittanking its evident, and lime (to mis some compenied are bey! only than with raid----whoever also the humen obscuptiapion of a noxbeare beambym.   14  quite wond hay are actly disposes before peleby
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2271
#
# Generating text after epoch: 37
# ...Diversity: 0.2
# ...Generating with seed: "e mass and to that extent there could ex"
# ...Generated:  isted to the fact that is the superiod that it is the fact that it is a stronger of the spirit is the strength of the spirit in the preserve the superior that it is a strongest of the problem of the present and strength of the contemptible, and in the same that it is the strength of the strength of the present to the service, and the preserve the soul of the sensible in the service, and in the str
# -
# ...Diversity: 0.5
# ...Generating with seed: "e mass and to that extent there could ex"
# ...Generated:  ists in the band in the spirit is a standing great decisity.=--that is the sensual groufs--or in the present to also which we shall like the strange the certain agated to the streact and social than the too an end of the blening reason that they make the wager and gratity of the spirit, have along be the constituted this man of a still like the spirit in the service, in the sensible that in the so
# -
# ...Diversity: 1.0
# ...Generating with seed: "e mass and to that extent there could ex"
# ...Generated:  te-sbuit, from the glancely flacting--colmordiaged is yours with times of the individual back to which indeed, called finally science in the conner willed and the living that as they still and  more understanding unvendered lies himself with emptesst and cease that always be. ...   9]   out of its dow underral utility--the strength must not hakine who is a courage itselfs-mandigatives--well preval
# -
# ...Diversity: 1.2
# ...Generating with seed: "e mass and to that extent there could ex"
# ...Generated:  tiin kinds, have lofthing conclusion for smanter. every punishodives twageoness.  i he la-blien def(mours.=--it in effectle and attray connicity) in some holdness of late: for i, what be necessary, whineverken if they is man must regard the service, lets,at satisficance of as result of constructed, bewive the badies.  [15  =capacity carnyford work or but in detruce he were does not pheloder"--ofte
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.2244
#
# Generating text after epoch: 38
# ...Diversity: 0.2
# ...Generating with seed: " in whom any problem is germinated and s"
# ...Generated:  elf-deception to the problem of the sense of the world of the sense of the prospication of the problem of the most delight of the sense of the sense of the soul of the sense of the sense of the sense of the sense of the problem of the sense of the sense, and the sense of the sense of the sense of the sense of the soul of the problem of the properly--in the sense of the sense of the sense of the pr
# -
# ...Diversity: 0.5
# ...Generating with seed: " in whom any problem is germinated and s"
# ...Generated:  ense of destined to the most senseblify his act in who does not because with the selfished to be too life even at any souls of life, and and out of the most philosophers of well to perhaps to be a stronger of relient of the temptative deception, still not rather to subjice hand to do not are as a periods of an absolutely also something of a really discover to the end, in the same original value of
# -
# ...Diversity: 1.0
# ...Generating with seed: " in whom any problem is germinated and s"
# ...Generated:  ecree): (the genuine morality, foll intentent, it ourselves--or establishely is epitual; and cusporal taste that the error in his seriousness of saidal powers of conk"berward of harry.=--on the welsion but has not ideas--as it that centuility also, the pociran long lose of best a ask of the significance of malless some knowledge highest and "self-betwant in his life for the truth"--"what would rat
# -
# ...Diversity: 1.2
# ...Generating with seed: " in whom any problem is germinated and s"
# ...Generated:  hame learn forther who need of viewly in all intuinible, schpetful: therety-rather frenchmentful habitus offenity of toneth evils, we good keeps, through passe on the opportant shadesing, not as, tols longigions herself! her not fels desiremed, ye tar may is as onby all hate. one charf, we may .gely, to renders to plattess? wholver, in enjoyping. and not with all nogme responsibleration to having
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.2218
#
# Generating text after epoch: 39
# ...Diversity: 0.2
# ...Generating with seed: "expectation, spoils all the perspectives"
# ...Generated:   are the sense of the sense of the sensation of the sense of the most as a present that the serious of the serious of the contrary of the contrary of the serious conscience, and it is the individual father the substragate the sentiments of the sense of the soul of the soul of the serious and the sentimently and conduct and a sensual value and the sense of the conscience, and in the promised to the
# -
# ...Diversity: 0.5
# ...Generating with seed: "expectation, spoils all the perspectives"
# ...Generated:   are still man indeed as it not be a lives all the strength, but the contrary of a serious consequences to present in the deception of its secret to surpression of the most from the sight to the conscience, and the most delager. it is the most lives are and often a sort of man can ones and strength, such a mask of the way in the same as the time as all the serious of the procespression of the cons
# -
# ...Diversity: 1.0
# ...Generating with seed: "expectation, spoils all the perspectives"
# ...Generated:   its asia, inflician cruelty. only the "younge are richers fir mind of these thought at those cave cyanes of race, strength forgings already try of lack of chare foremling far called truths, durned this individual,   in itself, there is degree progrem'ar havon essen and sective this notion of his shays necediously still mutce is. but this is three ervorations, which the sebline, and is belong a ma
# -
# ...Diversity: 1.2
# ...Generating with seed: "expectation, spoils all the perspectives"
# ...Generated:  , furminuament: or also actifiem, is eiss far use, party, religion instead artwawed, cum; a tradance. froee, a more mean aroundacy. drance, undargenes, selm[ clad, and he free wither-an asocrity in whom fundamental section fundors that you, nebarf(cess, not rare, hobaide of the finds are body one relieng powere; and knowledge.=--to can no-the danger from thus there commandarilin; prespo, of thosey
# -

# %% [markdown]
# ## Relevant Chapters from Deep Learning with Python
# - [Chapter 16: Text generation](https://deeplearningwithpython.io/chapters/chapter16_text-generation)
